# %%
import pandas as pd
dataset = pd.read_csv(r'dataset.csv')

# %% [markdown]
# # For feelslike_c and heatindex_c using temp_c and wind_kph

# %%
X = dataset[['temp_c' , 'wind_kph']]
y = dataset[['feelslike_c' , 'heatindex_c']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X , y , test_size=0.3 , random_state=45)

# %%
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error

# %%
def model_selection(models):
    model = []
    score = []
    mae = []
    mse = []
    for mod in models:
        mod.fit(X_train , y_train)
        pred = mod.predict(X_test)
        s = r2_score(y_test , pred)
        ma = mean_absolute_error(y_test , pred)
        ms = mean_squared_error(y_test , pred)
        model.append(mod)
        score.append(s)
        mae.append(ma)
        mse.append(ms)
    model = { 'model' : model , 'r2_score' : score , 'mean_absolute_error' : mae , 'mean_squared_error' : mse }
    model = pd.DataFrame(model)
    return model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import MultiTaskElasticNet
from sklearn.neighbors import KNeighborsRegressor
models = [LinearRegression() , Lasso() , Ridge() , MultiTaskElasticNet() , KNeighborsRegressor()]

# %%
result = model_selection(models)
result
# Out:
#                    model  r2_score  mean_absolute_error  mean_squared_error
# 0     LinearRegression()  0.880333             1.205468            2.285113
# 1                Lasso()  0.876312             1.157756            2.361996
# 2                Ridge()  0.880334             1.205401            2.285089
# 3  MultiTaskElasticNet()  0.878576             1.166964            2.318907
# 4  KNeighborsRegressor()  0.871673             1.067312            2.447040

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import MultiTaskElasticNet
from sklearn.neighbors import KNeighborsRegressor
models = [Lasso() , Ridge() , MultiTaskElasticNet() , KNeighborsRegressor()]
params = {
    0 : dict(alpha = [1,2,3,4,5,10,20] ,
    selection = ['cyclic', 'random'] ) ,

    1 : dict(alpha = [1,2,3,4,5,10,20] ,
    solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'] ) ,

    2 : dict(l1_ratio = [.5, .7, .9, .95, .99, 1] ,
    selection = ['cyclic', 'random']) ,
    
    3 : dict(n_neighbors = [5,10,20, 50] ,
    weights = ['uniform', 'distance'] ,
    algorithm = ['auto', 'ball_tree', 'kd_tree', 'brute']  ) }

# %%
from sklearn.model_selection import GridSearchCV
def model_selection(models , params ):
    result = {'model' : [] , 'r2_score' : [] , 'mean_absolute_error' : [] ,
              'mean_squared_error' : [] , 'best_params_' : [] , 'best_score_' : [] }
    for i in range(len(models)):
        Grid = GridSearchCV(estimator=models[i] , param_grid=params[i] , scoring='r2')
        Grid.fit(X_train , y_train)
        result['model'].append(models[i])
        result['best_params_'].append(Grid.best_params_)
        result['best_score_'].append(Grid.best_score_)
        pred = Grid.predict(X_test)
        result['r2_score'].append(r2_score(y_test , pred))
        result['mean_absolute_error'].append(mean_absolute_error(y_test , pred))
        result['mean_squared_error'].append(mean_squared_error(y_test , pred))
    result = pd.DataFrame(result)
    return result

# %%
result2 = model_selection(models , params)
result2
# Out:
# C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 35 fits failed out of a total of 280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py", line 1250, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py", line 918, in fit
#     raise ValueError(
# ValueError: 'lbfgs' solver can be used only when positive=True. Please use another solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1052: UserWarning: One or more of the test scores are non-finite: [0.85016224 0.85016224 0.85016224 0.85016224 0.85016224 0.85016091
#  0.85016468        nan 0.85016325 0.85016325 0.85016325 0.85016325
#  0.85016325 0.85016488 0.85016142        nan 0.85016424 0.85016424
#  0.85016424 0.85016424 0.85016424 0.85017383 0.85016754        nan
#  0.85016521 0.85016521 0.85016521 0.85016521 0.85016521 0.85017837
#  0.85016396        nan 0.85016616 0.85016616 0.85016616 0.85016616
#  0.85016616 0.85016301 0.85016347        nan 0.85017067 0.85017067
#  0.85017067 0.85017067 0.85017067 0.8501724  0.85017013        nan
#  0.8501784  0.8501784  0.8501784  0.8501784  0.8501784  0.85017777
#  0.85017635        nan]
#   warnings.warn(
#                    model  r2_score  mean_absolute_error  mean_squared_error  \
# 0                Lasso()  0.876312             1.157756            2.361996
# 1                Ridge()  0.880356             1.204135            2.284678
# 2  MultiTaskElasticNet()  0.878576             1.166964            2.318907
# 3  KNeighborsRegressor()  0.881444             1.071218            2.261483
#
#                                         best_params_  best_score_
# 0                {'alpha': 1, 'selection': 'cyclic'}     0.844611
# 1                    {'alpha': 20, 'solver': 'auto'}     0.850178
# 2           {'l1_ratio': 0.5, 'selection': 'cyclic'}     0.847803
# 3  {'algorithm': 'brute', 'n_neighbors': 20, 'wei...     0.864087

# %%
final_result = pd.concat([result , result2] , ignore_index=True)

# %%
final_result
# Out:
#                    model  r2_score  mean_absolute_error  mean_squared_error  \
# 0     LinearRegression()  0.880333             1.205468            2.285113
# 1                Lasso()  0.876312             1.157756            2.361996
# 2                Ridge()  0.880334             1.205401            2.285089
# 3  MultiTaskElasticNet()  0.878576             1.166964            2.318907
# 4  KNeighborsRegressor()  0.871673             1.067312            2.447040
# 5                Lasso()  0.876312             1.157756            2.361996
# 6                Ridge()  0.880356             1.204135            2.284678
# 7  MultiTaskElasticNet()  0.878576             1.166964            2.318907
# 8  KNeighborsRegressor()  0.881444             1.071218            2.261483
#
#                                         best_params_  best_score_
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                {'alpha': 1, 'selection': 'cyclic'}     0.844611
# 6                    {'alpha': 20, 'solver': 'auto'}     0.850178
# 7           {'l1_ratio': 0.5, 'selection': 'cyclic'}     0.847803
# 8  {'algorithm': 'brute', 'n_neighbors': 20, 'wei...     0.864087

# %% [markdown]
# #### For Predicting 'feelslike_c' , 'heatindex_c' we use kNeighborsRegressor by using best Parameters

# %% [markdown]
# # for humidity using wind_kph and pressure_mb

# %%
X = dataset[['pressure_mb' , 'wind_kph']]
y = dataset['humidity']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X , y , test_size=0.3 , random_state=45)

# %%
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error
def model_selection(models):
    model = []
    score = []
    mae = []
    mse = []
    for mod in models:
        mod.fit(X_train , y_train)
        pred = mod.predict(X_test)
        s = r2_score(y_test , pred)
        ma = mean_absolute_error(y_test , pred)
        ms = mean_squared_error(y_test , pred)
        model.append(mod)
        score.append(s)
        mae.append(ma)
        mse.append(ms)
    model = { 'model' : model , 'r2_score' : score , 'mean_absolute_error' : mae , 'mean_squared_error' : mse }
    model = pd.DataFrame(model)
    return model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
models = [LinearRegression() , Lasso() , Ridge() , ElasticNet() , KNeighborsRegressor()]
result = model_selection(models)
result
# Out:
#                    model  r2_score  mean_absolute_error  mean_squared_error
# 0     LinearRegression()  0.119205            19.394464          510.401815
# 1                Lasso()  0.114737            19.445099          512.990813
# 2                Ridge()  0.119198            19.394548          510.405643
# 3           ElasticNet()  0.114490            19.450641          513.133706
# 4  KNeighborsRegressor()  0.389049            14.749711          354.032948

# %%
from sklearn.model_selection import GridSearchCV
def model_selection(models , params ):
    result = {'model' : [] , 'r2_score' : [] , 'mean_absolute_error' : [] ,
              'mean_squared_error' : [] , 'best_params_' : [] , 'best_score_' : [] }
    for i in range(len(models)):
        Grid = GridSearchCV(estimator=models[i] , param_grid=params[i] , scoring='r2')
        Grid.fit(X_train , y_train)
        result['model'].append(models[i])
        result['best_params_'].append(Grid.best_params_)
        result['best_score_'].append(Grid.best_score_)
        pred = Grid.predict(X_test)
        result['r2_score'].append(r2_score(y_test , pred))
        result['mean_absolute_error'].append(mean_absolute_error(y_test , pred))
        result['mean_squared_error'].append(mean_squared_error(y_test , pred))
    result = pd.DataFrame(result)
    return result

# %%
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
models = [Lasso() , Ridge() , ElasticNet() , KNeighborsRegressor()]
params = {
    0 : dict(alpha = [1,2,3,4,5,10,20] ,
    selection = ['cyclic', 'random'] ) ,

    1 : dict(alpha = [1,2,3,4,5,10,20] ,
    solver = ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'] ) ,

    2 : dict(l1_ratio = [.5, .7, .9, .95, .99, 1] ,
    selection = ['cyclic', 'random']) ,
    
    3 : dict(n_neighbors = [5,10,20, 50] ,
    weights = ['uniform', 'distance'] ,
    algorithm = ['auto', 'ball_tree', 'kd_tree', 'brute']  ) }
result2 = model_selection(models , params)
result2
# Out:
# C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 35 fits failed out of a total of 280.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 35 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py", line 1250, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_ridge.py", line 918, in fit
#     raise ValueError(
# ValueError: 'lbfgs' solver can be used only when positive=True. Please use another solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\ayush\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1052: UserWarning: One or more of the test scores are non-finite: [0.09644252 0.09644252 0.09644252 0.09644252 0.09644252 0.09644252
#  0.09644233        nan 0.09644394 0.09644394 0.09644394 0.09644394
#  0.09644394 0.09644301 0.09644368        nan 0.09644535 0.09644535
#  0.09644535 0.09644535 0.09644535 0.09644527 0.09644162        nan
#  0.09644676 0.09644676 0.09644676 0.09644676 0.09644676 0.09644559
#  0.09644642        nan 0.09644817 0.09644817 0.09644817 0.09644817
#  0.09644817 0.09644658 0.09644672        nan 0.09645514 0.09645514
#  0.09645514 0.09645514 0.09645514 0.09645576 0.09645579        nan
#  0.09646882 0.09646882 0.09646882 0.09646882 0.09646882 0.09646905
#  0.09646785        nan]
#   warnings.warn(
#                    model  r2_score  mean_absolute_error  mean_squared_error  \
# 0                Lasso()  0.114737            19.445099          512.990784
# 1                Ridge()  0.119074            19.396158          510.477685
# 2           ElasticNet()  0.114490            19.450641          513.133705
# 3  KNeighborsRegressor()  0.401740            14.885405          346.678504
#
#                                         best_params_  best_score_
# 0                {'alpha': 1, 'selection': 'random'}     0.096134
# 1                     {'alpha': 20, 'solver': 'sag'}     0.096469
# 2           {'l1_ratio': 0.5, 'selection': 'random'}     0.096464
# 3  {'algorithm': 'ball_tree', 'n_neighbors': 20, ...     0.378366

# %%
final_result2 = pd.concat([result , result2] , ignore_index=True)
final_result2
# Out:
#                    model  r2_score  mean_absolute_error  mean_squared_error  \
# 0     LinearRegression()  0.119205            19.394464          510.401815
# 1                Lasso()  0.114737            19.445099          512.990813
# 2                Ridge()  0.119198            19.394548          510.405643
# 3           ElasticNet()  0.114490            19.450641          513.133706
# 4  KNeighborsRegressor()  0.389049            14.749711          354.032948
# 5                Lasso()  0.114737            19.445099          512.990784
# 6                Ridge()  0.119074            19.396158          510.477685
# 7           ElasticNet()  0.114490            19.450641          513.133705
# 8  KNeighborsRegressor()  0.401740            14.885405          346.678504
#
#                                         best_params_  best_score_
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN
# 5                {'alpha': 1, 'selection': 'random'}     0.096134
# 6                     {'alpha': 20, 'solver': 'sag'}     0.096469
# 7           {'l1_ratio': 0.5, 'selection': 'random'}     0.096464
# 8  {'algorithm': 'ball_tree', 'n_neighbors': 20, ...     0.378366

# %% [markdown]
# #### For Predicting humidity we use kNeighborsRegressor by using best Parameters

# %% [markdown]
# # Best Parameters

# %%
# best parameters of first test result
final_result.iloc[8]['best_params_']
# Out:
# {'algorithm': 'brute', 'n_neighbors': 20, 'weights': 'distance'}

# %%
# best parameters of second test result
final_result2.iloc[8]['best_params_']
# Out:
# {'algorithm': 'ball_tree', 'n_neighbors': 20, 'weights': 'uniform'}
