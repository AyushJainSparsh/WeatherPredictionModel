# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv(r'dataset.csv')
dataset.head()
# Out:
#    temp_c condition  wind_kph  pressure_mb  humidity  feelslike_c  heatindex_c
# 0    24.5     Clear       4.7       1004.0      41.0         25.1         25.1
# 1    24.2     Clear       4.7       1004.0      41.0         24.9         24.9
# 2    23.8     Clear       4.7       1004.0      41.0         24.8         24.8
# 3    23.5     Clear       4.7       1004.0      42.0         24.6         24.6
# 4    23.2     Clear       4.3       1004.0      43.0         24.6         24.6

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1152 entries, 0 to 1151
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temp_c       1152 non-null   float64
#  1   condition    1152 non-null   object
#  2   wind_kph     1152 non-null   float64
#  3   pressure_mb  1152 non-null   float64
#  4   humidity     1152 non-null   float64
#  5   feelslike_c  1152 non-null   float64
#  6   heatindex_c  1152 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 63.1+ KB

# %%
dataset.describe()
# Out:
#             temp_c     wind_kph  pressure_mb     humidity  feelslike_c  \
# count  1152.000000  1152.000000  1152.000000  1152.000000  1152.000000
# mean     27.165451     9.959288  1006.862847    62.105035    28.815885
# std       4.054966     5.122786     2.520520    23.929964     4.290599
# min      19.100000     0.400000  1002.000000    11.000000    19.100000
# 25%      24.000000     6.000000  1005.000000    42.000000    25.900000
# 50%      26.300000     9.600000  1007.000000    61.000000    27.800000
# 75%      29.700000    13.300000  1009.000000    85.000000    31.300000
# max      38.800000    27.400000  1012.000000    98.000000    43.200000
#
#        heatindex_c
# count  1152.000000
# mean     28.934809
# std       4.117000
# min      19.100000
# 25%      25.900000
# 50%      27.800000
# 75%      31.300000
# max      43.200000

# %%
plt.figure(figsize=(16 , 12))
sns.pairplot(dataset)
plt.savefig('pairplot.jpeg')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.histplot(dataset['condition'])
plt.xticks(rotation=45)
plt.savefig('hist.jpeg')
plt.show()
